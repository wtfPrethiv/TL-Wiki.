# %%
h = {
  "summary": {
    "History": {
      "sdkHttpResponse": {
        "headers": {
          "content-type": "application/json; charset=UTF-8",
          "vary": "Origin, X-Origin, Referer",
          "content-encoding": "gzip",
          "date": "Sun, 07 Sep 2025 11:00:28 GMT",
          "server": "scaffolding on HTTPServer2",
          "x-xss-protection": "0",
          "x-frame-options": "SAMEORIGIN",
          "x-content-type-options": "nosniff",
          "server-timing": "gfet4t7; dur=2728",
          "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000",
          "transfer-encoding": "chunked"
        },
        "body": None
      },
      "candidates": [
        {
          "content": {
            "parts": [
              {
                "videoMetadata": None,
                "thought": None,
                "inlineData": None,
                "fileData": None,
                "thoughtSignature": None,
                "codeExecutionResult": None,
                "executableCode": None,
                "functionCall": None,
                "functionResponse": None,
                "text": "Visual Studio Code was first announced by Microsoft on April 29, 2015, at the Build conference, with a preview build released soon after. On November 18, 2015, its underlying open-source project, \"Code – OSS,\" was released under the MIT License on GitHub, and extension support was also announced. Visual Studio Code exited its public preview stage and was officially released to the web on April 14, 2016."
              }
            ],
            "role": "model"
          },
          "citationMetadata": None,
          "finishMessage": None,
          "tokenCount": None,
          "finishReason": "STOP",
          "urlContextMetadata": None,
          "avgLogprobs": None,
          "groundingMetadata": None,
          "index": 0,
          "logprobsResult": None,
          "safetyRatings": None
        }
      ],
      "createTime": None,
      "modelVersion": "gemini-2.5-flash",
      "promptFeedback": None,
      "responseId": "zGW9aP-ACouDmtkP-sXZ0AE",
      "usageMetadata": {
        "cacheTokensDetails": None,
        "cachedContentTokenCount": None,
        "candidatesTokenCount": 100,
        "candidatesTokensDetails": None,
        "promptTokenCount": 255,
        "promptTokensDetails": [
          {
            "modality": "TEXT",
            "tokenCount": 255
          }
        ],
        "thoughtsTokenCount": 141,
        "toolUsePromptTokenCount": None,
        "toolUsePromptTokensDetails": None,
        "totalTokenCount": 496,
        "trafficType": None
      },
      "automaticFunctionCallingHistory": [],
      "parsed": None
    },
    "Features": {
      "sdkHttpResponse": {
        "headers": {
          "content-type": "application/json; charset=UTF-8",
          "vary": "Origin, X-Origin, Referer",
          "content-encoding": "gzip",
          "date": "Sun, 07 Sep 2025 11:00:39 GMT",
          "server": "scaffolding on HTTPServer2",
          "x-xss-protection": "0",
          "x-frame-options": "SAMEORIGIN",
          "x-content-type-options": "nosniff",
          "server-timing": "gfet4t7; dur=11008",
          "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000",
          "transfer-encoding": "chunked"
        },
        "body": None
      },
      "candidates": [
        {
          "content": {
            "parts": [
              {
                "videoMetadata": None,
                "thought": None,
                "inlineData": None,
                "fileData": None,
                "thoughtSignature": None,
                "codeExecutionResult": None,
                "executableCode": None,
                "functionCall": None,
                "functionResponse": None,
                "text": "Visual Studio Code is a widely used source-code editor supporting a broad range of programming languages, including C, Python, and Java. It is available both as a downloadable application built on the Electron framework and as a browser-based version, vscode.dev, for editing local and remote files. Key features include syntax highlighting, bracket matching, code folding, configurable snippets, IntelliSense for languages like JavaScript and HTML, and built-in debugging support for Node.js, extendable for other languages via marketplace extensions. The debugger allows developers to attach to processes, step through code, set breakpoints, monitor variables, and use an integrated Debug Console for real-time expression evaluation.\n\nInstead of a project system, VS Code manages development through opening directories as workspaces, making it language-agnostic. Many functionalities are accessible via the keyboard-driven Command Palette, complementing its user interface. It also provides a fully featured integrated terminal supporting various shells, with enhancements like clickable file links and error detection to aid navigation and debugging.\n\nThe editor is highly extensible through its Marketplace, offering extensions for language support, themes, debuggers, and other utilities. It includes built-in source control integration, allowing users to manage systems like Git directly for tasks such as viewing changes and handling repositories. VS Code also supports remote development via extensions like Remote-SSH and Remote-Containers, and its web version facilitates browser-based access. Microsoft collects usage data to improve the product, a telemetry feature that can be disabled. An \"Insiders\" version provides nightly builds for early access to new features, operating independently of the stable release."
              }
            ],
            "role": "model"
          },
          "citationMetadata": None,
          "finishMessage": None,
          "tokenCount": None,
          "finishReason": "STOP",
          "urlContextMetadata": None,
          "avgLogprobs": None,
          "groundingMetadata": None,
          "index": 0,
          "logprobsResult": None,
          "safetyRatings": None
        }
      ],
      "createTime": None,
      "modelVersion": "gemini-2.5-flash",
      "promptFeedback": None,
      "responseId": "12W9aLe7C9TiqtsPltXtyQY",
      "usageMetadata": {
        "cacheTokensDetails": None,
        "cachedContentTokenCount": None,
        "candidatesTokenCount": 322,
        "candidatesTokensDetails": None,
        "promptTokenCount": 1428,
        "promptTokensDetails": [
          {
            "modality": "TEXT",
            "tokenCount": 1428
          }
        ],
        "thoughtsTokenCount": 1595,
        "toolUsePromptTokenCount": None,
        "toolUsePromptTokensDetails": None,
        "totalTokenCount": 3345,
        "trafficType": None
      },
      "automaticFunctionCallingHistory": [],
      "parsed": None
    },
    "Reception": {
      "sdkHttpResponse": {
        "headers": {
          "content-type": "application/json; charset=UTF-8",
          "vary": "Origin, X-Origin, Referer",
          "content-encoding": "gzip",
          "date": "Sun, 07 Sep 2025 11:00:41 GMT",
          "server": "scaffolding on HTTPServer2",
          "x-xss-protection": "0",
          "x-frame-options": "SAMEORIGIN",
          "x-content-type-options": "nosniff",
          "server-timing": "gfet4t7; dur=1959",
          "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000",
          "transfer-encoding": "chunked"
        },
        "body": None
      },
      "candidates": [
        {
          "content": {
            "parts": [
              {
                "videoMetadata": None,
                "thought": None,
                "inlineData": None,
                "fileData": None,
                "thoughtSignature": None,
                "codeExecutionResult": None,
                "executableCode": None,
                "functionCall": None,
                "functionResponse": None,
                "text": "Visual Studio Code's popularity significantly increased in the Stack Overflow Developer Surveys. In 2016, it ranked 13th with 7% of respondents using it. By 2018, it rose to the number one spot, used by 35% of respondents, and has retained this position ever since. Its usage continued to grow, reaching 50% in 2019, 74.5% in 2021, 74.48% in 2022, 73.71% in 2023, 73.6% in 2024, and 75.9% in 2025."
              }
            ],
            "role": "model"
          },
          "citationMetadata": None,
          "finishMessage": None,
          "tokenCount": None,
          "finishReason": "STOP",
          "urlContextMetadata": None,
          "avgLogprobs": None,
          "groundingMetadata": None,
          "index": 0,
          "logprobsResult": None,
          "safetyRatings": None
        }
      ],
      "createTime": None,
      "modelVersion": "gemini-2.5-flash",
      "promptFeedback": None,
      "responseId": "2WW9aOGQCvmVmtkP6IrM2QI",
      "usageMetadata": {
        "cacheTokensDetails": None,
        "cachedContentTokenCount": None,
        "candidatesTokenCount": 155,
        "candidatesTokensDetails": None,
        "promptTokenCount": 328,
        "promptTokensDetails": [
          {
            "modality": "TEXT",
            "tokenCount": 328
          }
        ],
        "thoughtsTokenCount": 113,
        "toolUsePromptTokenCount": None,
        "toolUsePromptTokensDetails": None,
        "totalTokenCount": 596,
        "trafficType": None
      },
      "automaticFunctionCallingHistory": [],
      "parsed": None
    },
    "See also": {
      "sdkHttpResponse": {
        "headers": {
          "content-type": "application/json; charset=UTF-8",
          "vary": "Origin, X-Origin, Referer",
          "content-encoding": "gzip",
          "date": "Sun, 07 Sep 2025 11:00:45 GMT",
          "server": "scaffolding on HTTPServer2",
          "x-xss-protection": "0",
          "x-frame-options": "SAMEORIGIN",
          "x-content-type-options": "nosniff",
          "server-timing": "gfet4t7; dur=4074",
          "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000",
          "transfer-encoding": "chunked"
        },
        "body": None
      },
      "candidates": [
        {
          "content": {
            "parts": [
              {
                "videoMetadata": None,
                "thought": None,
                "inlineData": None,
                "fileData": None,
                "thoughtSignature": None,
                "codeExecutionResult": None,
                "executableCode": None,
                "functionCall": None,
                "functionResponse": None,
                "text": "The provided content lists several related topics and development tools. These include the Free and open-source software portal, a comparison of integrated development environments, GitHub Copilot, and GitHub Codespaces, an online integrated development environment resembling VS Code. Additionally, Visual Studio and Eclipse Theia are mentioned among the related items."
              }
            ],
            "role": "model"
          },
          "citationMetadata": None,
          "finishMessage": None,
          "tokenCount": None,
          "finishReason": "STOP",
          "urlContextMetadata": None,
          "avgLogprobs": None,
          "groundingMetadata": None,
          "index": 0,
          "logprobsResult": None,
          "safetyRatings": None
        }
      ],
      "createTime": None,
      "modelVersion": "gemini-2.5-flash",
      "promptFeedback": None,
      "responseId": "3WW9aOHED6ujqtsP7Ke0sAI",
      "usageMetadata": {
        "cacheTokensDetails": None,
        "cachedContentTokenCount": None,
        "candidatesTokenCount": 62,
        "candidatesTokensDetails": None,
        "promptTokenCount": 145,
        "promptTokensDetails": [
          {
            "modality": "TEXT",
            "tokenCount": 145
          }
        ],
        "thoughtsTokenCount": 650,
        "toolUsePromptTokenCount": None,
        "toolUsePromptTokensDetails": None,
        "totalTokenCount": 857,
        "trafficType": None
      },
      "automaticFunctionCallingHistory": [],
      "parsed": None
    },
    "References": {
      "sdkHttpResponse": {
        "headers": {
          "content-type": "application/json; charset=UTF-8",
          "vary": "Origin, X-Origin, Referer",
          "content-encoding": "gzip",
          "date": "Sun, 07 Sep 2025 11:00:46 GMT",
          "server": "scaffolding on HTTPServer2",
          "x-xss-protection": "0",
          "x-frame-options": "SAMEORIGIN",
          "x-content-type-options": "nosniff",
          "server-timing": "gfet4t7; dur=1311",
          "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000",
          "transfer-encoding": "chunked"
        },
        "body": None
      },
      "candidates": [
        {
          "content": {
            "parts": [
              {
                "videoMetadata": None,
                "thought": None,
                "inlineData": None,
                "fileData": None,
                "thoughtSignature": None,
                "codeExecutionResult": None,
                "executableCode": None,
                "functionCall": None,
                "functionResponse": None,
                "text": "The provided content consists entirely of references and does not contain any information to summarize."
              }
            ],
            "role": "model"
          },
          "citationMetadata": None,
          "finishMessage": None,
          "tokenCount": None,
          "finishReason": "STOP",
          "urlContextMetadata": None,
          "avgLogprobs": None,
          "groundingMetadata": None,
          "index": 0,
          "logprobsResult": None,
          "safetyRatings": None
        }
      ],
      "createTime": None,
      "modelVersion": "gemini-2.5-flash",
      "promptFeedback": None,
      "responseId": "3mW9aM3GI5eIqtsP8tmI4QI",
      "usageMetadata": {
        "cacheTokensDetails": None,
        "cachedContentTokenCount": None,
        "candidatesTokenCount": 16,
        "candidatesTokensDetails": None,
        "promptTokenCount": 2352,
        "promptTokensDetails": [
          {
            "modality": "TEXT",
            "tokenCount": 2352
          }
        ],
        "thoughtsTokenCount": 87,
        "toolUsePromptTokenCount": None,
        "toolUsePromptTokensDetails": None,
        "totalTokenCount": 2455,
        "trafficType": None
      },
      "automaticFunctionCallingHistory": [],
      "parsed": None
    },
    "External links": {
      "sdkHttpResponse": {
        "headers": {
          "content-type": "application/json; charset=UTF-8",
          "vary": "Origin, X-Origin, Referer",
          "content-encoding": "gzip",
          "date": "Sun, 07 Sep 2025 11:00:54 GMT",
          "server": "scaffolding on HTTPServer2",
          "x-xss-protection": "0",
          "x-frame-options": "SAMEORIGIN",
          "x-content-type-options": "nosniff",
          "server-timing": "gfet4t7; dur=8112",
          "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000",
          "transfer-encoding": "chunked"
        },
        "body": None
      },
      "candidates": [
        {
          "content": {
            "parts": [
              {
                "videoMetadata": None,
                "thought": None,
                "inlineData": None,
                "fileData": None,
                "thoughtSignature": None,
                "codeExecutionResult": None,
                "executableCode": None,
                "functionCall": None,
                "functionResponse": None,
                "text": "The provided content outlines a comprehensive collection of software, tools, programming languages, and frameworks predominantly related to Microsoft, software development, and web design. It encompasses a wide range of Microsoft development environments, including various Visual Studio editions, alongside tools like Expression Web, Robotics Developer Studio, and the Windows App SDK. Numerous programming languages are listed, such as C++, C#, F#, Visual Basic, JavaScript, TypeScript, Python, Ruby, and PowerShell, including specific Microsoft implementations. The list also details diverse .NET technologies like ASP.NET Core, Entity Framework, WPF, and WCF, in addition to Windows development technologies such as UWP, DirectX, and WinUI. Furthermore, it covers an extensive array of web design tools, content editors, JavaScript frameworks, libraries, development aids including package managers like npm and NuGet, build tools like Webpack, and testing frameworks such as xUnit.net, collectively representing a broad ecosystem for application, web, and system development."
              }
            ],
            "role": "model"
          },
          "citationMetadata": None,
          "finishMessage": None,
          "tokenCount": None,
          "finishReason": "STOP",
          "urlContextMetadata": None,
          "avgLogprobs": None,
          "groundingMetadata": None,
          "index": 0,
          "logprobsResult": None,
          "safetyRatings": None
        }
      ],
      "createTime": None,
      "modelVersion": "gemini-2.5-flash",
      "promptFeedback": None,
      "responseId": "5mW9aKbnKteLmtkPrtPxkA0",
      "usageMetadata": {
        "cacheTokensDetails": None,
        "cachedContentTokenCount": None,
        "candidatesTokenCount": 194,
        "candidatesTokensDetails": None,
        "promptTokenCount": 1032,
        "promptTokensDetails": [
          {
            "modality": "TEXT",
            "tokenCount": 1032
          }
        ],
        "thoughtsTokenCount": 1254,
        "toolUsePromptTokenCount": None,
        "toolUsePromptTokensDetails": None,
        "totalTokenCount": 2480,
        "trafficType": None
      },
      "automaticFunctionCallingHistory": [],
      "parsed": None
    }
  }
}

# %%
from backend.services.scraper import Scraper
scraper = Scraper()
    
wiki_content = scraper.scrape('drake')

wiki_content

# %%
from backend.services.translator import TranslatorService

trans_zh = TranslatorService(source='en', target='zh-CN')
content_zh = trans_zh.translate(wiki_content)

content_zh

# %%
from backend.services.gemini import Gemini

gemini = Gemini()
summarized_content = gemini.ai_summarize(content_zh)

print("Gemini output:", summarized_content)

# %%
type(summarized_content)
# Out:
# dict

# %%
from backend.services.extractor import Extractor
extnew = Extractor(summarized_content)
extnew.extract()
# Out:
# {}

# %%
# Out:
# {'Animals and creatures': 'MALEDUCKDRAKE is a mythical creature, a term related to and often synonymous with Dragon.',
#  'People and fictional characters': 'The content lists several individuals and names. Sir Francis Drake (1540–1596) was an English explorer and privateer. Drake is also mentioned as a surname. Rake is noted as a given name, and a musician named Rake was born in 1986.',
#  'Places': 'Places named Drake include several unincorporated communities in the United States across Arizona, Colorado, Illinois, Kentucky, Missouri, and North Dakota, as well as a town in North Carolina near Nash County and Franklin Hart Farmdreake in South Carolina. In Antarctica, the Drake Passage is located near Cape Horn and the head of Oates Land, and Drake Icefall is in Ellsworth Land. Australia has Drake County and Drake, a parish and rural community, both in New South Wales. Additionally, there is a village named Drake in Saskatchewan, Canada, and a Lewisham Ward.',
# ...
